# %% [markdown]
# # Exploratory Data Analysis for HOG (histogram of gradients)

# %% [markdown]
# Import libraries:

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Some Matplotlib configuration:

# %%
font = { 'family': 'DejaVu Sans', 'weight': 'bold', 'size': 22 }
plt.rc('font', **font)

# %% [markdown]
# Import the config file which contains all the paths:

# %%
import sys

# %%
sys.path.append('..')

# %%
import config

# %% [markdown]
# **HOG Features**

# %%
config.DEV_FEATURES
# Out:
# '/datasets/dev-set/features'

# %%
config.DEV_FEATURES_LIST
# Out:
# ['C3D',
#  'HMP',
#  'InceptionV3',
#  'LBP',
#  'aesthetic_feat_dev-set_mean',
#  'ColorHistogram',
#  'HOG',
#  'ORB']

# %%
config.DEV_HOG_FEATURE
# Out:
# '/datasets/dev-set/features/HOG'

# %%
HOG_FILENAMES = os.listdir(config.DEV_HOG_FEATURE)

# %%
HOG_FILENAMES[:5]
# Out:
# ['video818-0.txt',
#  'video3493-112.txt',
#  'video6172-0.txt',
#  'video1264-0.txt',
#  'video3776-56.txt']

# %%
len(HOG_FILENAMES)
# Out:
# 24000

# %%
video_names = list(set([ video.split('-')[0] for video in HOG_FILENAMES ]))

# %%
len(video_names)
# Out:
# 8000

# %%
def read_features(video_name, frame, feature_name):
    filename = '{}-{}.txt'.format(video_name, frame)
    with open(filename) as f:
        return { '{}_{}_{}'.format(feature_name, frame, i + 1) : float(feature) 
                for i, feature in enumerate(f.read().split()) }

# %%
NUM_FEATURES = len(read_features(os.path.join(config.DEV_HOG_FEATURE, video_names[0]), 0, 'HOG'))

# %%
for video in video_names:
    print(video, len(read_features(os.path.join(config.DEV_HOG_FEATURE, video), 0, 'HOG')))
# Out:
# video6499 9575
# video7235 12367
# video998 8954
# video5445 11849
# video1204 11002
# video1177 7058
# video7956 8867
# video3193 13494
# video7038 11821
# video7664 12501
# video5961 12604
# video7090 13961
# video9959 12123
# video7909 12843
# video2074 13240
# video2256 6330
# video3489 7211
# video6007 2253
# video1150 10802
# video1253 4736
# video1017 12055
# video3696 12814
# video8695 10360
# video5968 8911
# video6169 14334
# video2052 12053
# video2376 12050
# video8498 12709
# video3035 12240
# video2424 12828
# video8487 9171
# video9733 10581
# video7678 12586
# video6694 8081
# video3838 12933
# video7405 12403
# video1241 12138
# video8516 11457
# video4525 11746
# video626 8729
# video7967 10296
# video1838 13715
# video5491 13137
# video5398 13080
# video6670 11379
# video7050 12432
# video6182 11393
# video7211 8495
# video7341 10406
# video2836 4941
# video7555 11997
# video5897 9274
# video6894 11827
# video8002 12193
# video9815 9608
# video120 10394
# video8674 9966
# video9313 12713
# video6596 10049
# video6885 9151
# video571 9910
# video899 10375
# video3590 8987
# video2583 10882
# video8632 5356
# video7378 12300
# video806 14349
# video9479 11933
# video8016 10940
# video8779 13172
# video1458 10713
# video5845 12691
# video7589 9875
# video8425 8340
# video8616 6326
# video2515 8365
# video5248 10418
# video8878 6728
# video7219 9458
# video3673 7574
# video2947 10341
# video123 7923
# video7585 10533
# video7264 12284
# video1800 1
# video9765 11386
# video4749 11342
# video4242 9527
# video8956 9353
# video6890 9971
# video4501 12306
# video2257 9662
# video4989 9593
# video4275 10028
# video2693 8567
# video10 11715
# video6215 6492
# video1415 12234
# video9460 7827
# video7496 13246
# video5037 13263
# video5357 12934
# video5459 11954
# video5657 13078
# video9232 8392
# video2584 11167
# video410 10061
# video6983 8689
# video2314 8844
# video5794 11042
# video8640 13851
# video9747 5000
# video6230 8133
# video8030 9073
# video3145 9721
# video1629 9896
# video9981 11322
# video3079 6048
# video6964 13412
# video2691 8348
# video6851 13098
# video1964 11419
# video7725 12243
# video7293 8403
# video4870 12417
# video7291 13877
# video6710 11222
# video7179 12076
# video6382 5902
# video8859 10883
# video2991 12836
# video1619 12268
# video3077 11725
# video4734 12875
# video2649 5611
# video2551 13462
# video3583 8526
# video1537 13932
# video1639 6671
# video3895 12757
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-2f4a1c50565f> in <module>
#       1 for video in video_names:
# ----> 2     print(video, len(read_features(os.path.join(config.DEV_HOG_FEATURE, video), 0, 'HOG')))
#
# <ipython-input-14-70b391840cb4> in read_features(video_name, frame, feature_name)
#       3     with open(filename) as f:
#       4         return { '{}_{}_{}'.format(feature_name, frame, i + 1) : float(feature)
# ----> 5                 for i, feature in enumerate(f.read().split()) }
#
# <ipython-input-14-70b391840cb4> in <dictcomp>(.0)
#       3     with open(filename) as f:
#       4         return { '{}_{}_{}'.format(feature_name, frame, i + 1) : float(feature)
# ----> 5                 for i, feature in enumerate(f.read().split()) }
#
# KeyboardInterrupt:

# %%
NUM_FEATURES
# Out:
# 9575

# %%
def read_features_optimized(video_name, frame):
    filename = '{}-{}.txt'.format(video_name, frame)
    with open(filename) as f:
        return ','.join(f.read().split())

# %%
# read_features_optimized(os.path.join(config.DEV_HOG_FEATURE, video_names[0]), 0).split()

# %%
frames = [0, 56, 112]

# %%
# [ 'HOG_{}_{}'.format(frame, i) for frame in frames for i in range(NUM_FEATURES)  ]

# %%
with open('../../data/HOG_train.csv', 'w') as f: 
    # Header
    header = 'video,' + ','.join([ 'HOG_{}_{}'.format(frame, i) for frame in frames for i in range(NUM_FEATURES)  ])
    f.write(header + '\n')
    # Rows
    for i, video in enumerate(video_names):
        # print('Iteration: {}'.format(i))
        # Get features per video
        video_features = video.split('.txt')[0] + '.webm'
        for frame in frames:
            video_features += ',' + read_features_optimized(os.path.join(config.DEV_HOG_FEATURE, video), frame)
        # write it!
        f.write(video_features + '\n')

# %%
# !cat '../../data/HOG_train.csv' | wc -l
# Out:
# 8001

# %%
HOG_train_df = pd.read_csv('../../data/HOG_train.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-23-f5bcb482b38f> in <module>
# ----> 1 HOG_train_df = pd.read_csv('../../data/HOG_train.csv')
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     433
#     434     try:
# --> 435         data = parser.read(nrows)
#     436     finally:
#     437         parser.close()
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# /usr/local/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 29663 fields in line 3, saw 35582

# %%
# videos have different HOGs depending on the image...
